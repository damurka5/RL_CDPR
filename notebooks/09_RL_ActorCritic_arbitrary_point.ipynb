# %%
import os 
import torch
import torch.nn as nn
import torch.nn.functional as F 
import numpy as np
import gym
import warnings
from torch.distributions.categorical import Categorical
warnings.simplefilter("ignore")
from robot_model import *
torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cpu")

# %%
from gymnasium import spaces

class CDPR4_env(CDPR4):
    def __init__(self, start_state=np.array([.0, .0, 1.0, .0, .0, .0]), desired_state=np.array([.0, .0, 2.0, .0, .0, .0]), pos=np.array([.0, .0, 1.0]), params=params, approx=1, mass=1):
        super().__init__(pos=np.array([.0, .0, 1.]), params=params, approx=1, mass=1)

         # start position 1m on Z
        
        self.reward = 0 # reward 0 is 0 error in position, closer position to desired -> higher reward 
        
        self.v = np.array([-1.0, -1.0, -1.0]) # normalized, -1 is zero vel
        self.control = np.array([.0, .0, .0, .0])
    
        self.max_speed = 2
        self.max_force = 15 
        self.dt = 0.1
        
        self.action_space = spaces.Discrete(16) # [_,_,_,_] each place 0/1
        self.action_decoder = {
            i: np.array([int(b) for b in f'{i:04b}']) for i in range(16)
        }
        self.observation_space = spaces.Box(low=np.array([-1.154+0.15, -1.404+0.15, .0+0.15, -self.max_speed, -self.max_speed, -self.max_speed]), 
                                            high=np.array([1.154-0.15, 1.404-0.15, 3.220-0.15,  self.max_speed, self.max_speed, self.max_speed])) # decreased by 0.15m on each side to avoid over-tension
        self._max_episode_steps = 500 # default in gymnasium env is 1000
        self._elapsed_steps = 0
        
        self.start_state = self.normalize(start_state) 
        self.desired_state = self.normalize(desired_state)
        self.cur_state = self.normalize(np.array([.0, .0, 1., .0, .0, .0])) # X=[pos, vel] in control
        
    def normalize(self, value):
        min_val = self.observation_space.low
        max_val = self.observation_space.high
        normalized_value = 2 * (value - min_val) / (max_val - min_val) - 1
        # print(f'min_val {min_val}, max_val {max_val}, normalized_value {normalized_value}')
        return normalized_value
    
    def decode(self, normalized_value):
        min_val = self.observation_space.low
        max_val = self.observation_space.high
        original_value = ((normalized_value + 1) / 2) * (max_val - min_val) + min_val
        return original_value
        
    def reset(self):
        state = self.observation_space.sample()
        state_d = self.observation_space.sample()
        state_d[3:] = np.array([.0, .0, .0,]) # zero velocities at desired point
        self.desired_state = self.normalize(state_d)
        self.cur_state = self.normalize(state)
        
        self._elapsed_steps = 0
        self.pos = state[:3].flatten()
        self.v = state[3:].flatten()
        
        self.reward = -np.linalg.norm(self.pos - self.desired_state[:3].flatten())
        
        return self.normalize(state), self.normalize(state_d), {}
    
    def step(self, action):
        decoded_cur_state = self.decode(self.cur_state.flatten())
        pos = decoded_cur_state[:3]
        vel = decoded_cur_state[3:]
        # print(f'pos {pos}, vel {vel}')
        m = self.m

        dt = self.dt
        u = self.max_force*self.action_decoder[action].reshape((4,1))
        
        decoded_des_state = self.decode(self.desired_state.flatten())
        costs = np.linalg.norm(pos - decoded_des_state[:3])
        costs += 0.5*np.linalg.norm(vel - decoded_des_state[3:])
        
        # X_dot = AX + BU + G, where A[0:3, 3:6] is Identity matrix
        dXdt = np.hstack((vel, np.zeros((3,)))).reshape((6,1)) + self.B() @ u + np.array([.0, .0, .0, .0, .0, -g]).reshape((6,1))

        X = decoded_cur_state + dt*dXdt.flatten()

        self.pos = X[:3]#new_pos
        self.v = X[3:]#new_vel

        state = self.normalize(X)
        self.cur_state = state
        terminated = np.allclose(self.decode(self.cur_state), self.decode(self.desired_state), atol=1e-03) # reached desired position
        self._elapsed_steps += 1
        
        truncated = False
        if self._elapsed_steps >= self._max_episode_steps:
            truncated = True
        
        # state = np.hstack((state, self.desired_state))
        return state, -costs, terminated, truncated, {} #

# %%
env = CDPR4_env()

# %%
class ActorCriticNetwork(nn.Module):
    def __init__(self, n_observations, n_actions, fc1_dims=1024, fc2_dims=512):
        super(ActorCriticNetwork, self).__init__()
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions

        self.fc1 = nn.Linear(n_observations, self.fc1_dims)  # Assuming input size is 4
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.v = nn.Linear(self.fc2_dims, 1)
        self.pi = nn.Linear(self.fc2_dims, n_actions)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))

        v = self.v(x)
        pi = F.softmax(self.pi(x), dim=-1)

        return v, pi

# %%
from torch.distributions import Categorical
import torch.optim as optim

class Agent:
    def __init__(self, alpha=0.0003, gamma=0.99, n_observations=12, n_actions=16):
        self.gamma = gamma
        self.n_actions = n_actions
        self.action = None
        self.action_space = [i for i in range(self.n_actions)]

        self.actor_critic = ActorCriticNetwork(n_observations=n_observations, n_actions=n_actions)
        self.optimizer = optim.Adam(self.actor_critic.parameters(), lr=alpha)

    def choose_action(self, observation):
        # state = torch.tensor([observation], dtype=torch.float32)
        _, probs = self.actor_critic(observation)

        action_probabilities = Categorical(probs)
        action = action_probabilities.sample()
        log_prob = action_probabilities.log_prob(action)
        self.action = action

        return action.item()

    def learn(self, state, reward, state_, done):
        state = np.hstack((state, env.desired_state))
        state_ = np.hstack((state_, env.desired_state))
        state = torch.tensor([state], dtype=torch.float32)        
        state_ = torch.tensor([state_], dtype=torch.float32)
        reward = torch.tensor(reward, dtype=torch.float32)

        self.optimizer.zero_grad()

        state_value, probs = self.actor_critic(state)
        state_value_, _ = self.actor_critic(state_)
        state_value = torch.squeeze(state_value)
        state_value_ = torch.squeeze(state_value_)

        action_probs = Categorical(probs)
        log_prob = action_probs.log_prob(self.action)

        delta = reward + self.gamma * state_value_ * (1 - int(done)) - state_value
        actor_loss = -log_prob * delta.detach()
        critic_loss = delta.pow(2)
        total_loss = actor_loss + critic_loss

        total_loss.backward()
        self.optimizer.step()

# %%
from tqdm import tqdm
agent = Agent(alpha=1e-5, n_observations=2*env.observation_space.shape[0], n_actions=env.action_space.n)
# ac_model = agent.actor_critic
# ac_model.load_state_dict(torch.load('models/09_ActorCritic_single_linearReward_', weights_only=True))

n_games = 2400

best_score = -150
score_history = []

pbar = tqdm(range(n_games), desc="Training Progress")

for i in pbar:
    observation, desired_state, _ = env.reset() # normalized values
    obs_plus_des = torch.hstack((torch.from_numpy(observation), torch.from_numpy(desired_state)))
    done = False
    trunc = False
    score = 0
    while not (done or trunc):
        action = agent.choose_action(obs_plus_des.float())
        observation_, reward, done, trunc, info = env.step(action) # normalized value
        score += reward
        agent.learn(observation, reward, observation_, done)
        observation = observation_
        obs_plus_des = torch.hstack((torch.from_numpy(observation), torch.from_numpy(desired_state)))
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if score > best_score:
        best_score = score
        # torch.save(agent.actor_critic.state_dict(), f'models/07_ActorCritic_separate_linearReward_21_11_24_reward{int(score)}')
        
    pbar.set_postfix({
            'Episode Reward': f'{float(score):.5f}',
            'avg_score': f'{float(avg_score):.5f}',
            'pos':f'{env.pos}'
            
        })
    # print('episode ', i, 'score %.1f' % score, 'avg_score %.1f' % avg_score)
# Out:
# Training Progress: 100%|██████████| 2400/2400 [1:18:06<00:00,  1.95s/it, Episode Reward=-347.46297, avg_score=-388.42909, pos=[ 0.49072376 -0.15920541  1.95630839]]

# %%
pbar = tqdm(range(1000), desc="Training Progress")

for i in pbar:
    observation, desired_state, _ = env.reset() # normalized values
    obs_plus_des = torch.hstack((torch.from_numpy(observation), torch.from_numpy(desired_state)))
    done = False
    trunc = False
    score = 0
    while not (done or trunc):
        action = agent.choose_action(obs_plus_des.float())
        observation_, reward, done, trunc, info = env.step(action) # normalized value
        score += reward
        agent.learn(observation, reward, observation_, done)
        observation = observation_
        obs_plus_des = torch.hstack((torch.from_numpy(observation), torch.from_numpy(desired_state)))
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if score > best_score:
        best_score = score
        # torch.save(agent.actor_critic.state_dict(), f'models/07_ActorCritic_separate_linearReward_21_11_24_reward{int(score)}')
        
    pbar.set_postfix({
            'Episode Reward': f'{float(score):.5f}',
            'avg_score': f'{float(avg_score):.5f}',
            'pos':f'{env.pos}'
            
        })
# Out:
# Training Progress: 100%|██████████| 1000/1000 [35:42<00:00,  2.14s/it, Episode Reward=-398.57694, avg_score=-316.01250, pos=[-0.76937568  0.49968246  2.67824442]]

# %%
import matplotlib.pyplot as plt

plt.plot(range(1000), score_history[-1000:])
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.show()

# %%
# torch.save(agent.actor_critic.state_dict(), 'models/09_ActorCritic_single_linearReward_zerovel_dp_26_11_24_1800eps_-272')
